# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline
sns.set_palette("deep")
amazon = pd.read_csv("amazon_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0f48b1dc84df> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5 sns.set(color_codes=True)
#
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Capture the original matplotlib rcParams
# ----> 2 import matplotlib as mpl
#       3 _orig_rc_params = mpl.rcParams.copy()
#       4
#       5 # Import seaborn objects
#
# F:\Users\Debadutta\anaconda3\lib\site-packages\matplotlib\__init__.py in <module>
#     105 # cbook must import matplotlib only within function
#     106 # definitions, so it is safe to import from it here.
# --> 107 from . import cbook, rcsetup
#     108 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
# ...

# %%
amazon.head()
sns.pairplot(amazon[['mrp','sale price','discount percentage']],kind='kde')
plt.xticks(rotation=90)

# %%
sns.distplot(amazon['discount percentage'],hist=False)
plt.show()
# Out:
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#sns.distplot(forbes["Age"],kde=False,rug=True)
sns.distplot(forbes["Age"])
# Out:
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.jointplot(forbes["Rank"],forbes["Age"],kind='kde');
# Out:
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(forbes[['Rank','Age','Net Worth']],kind='kde')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-413e9126bf18> in <module>
# ----> 1 sns.pairplot(forbes[['Rank','Age','Net Worth']],kind='kde')
#
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1978     elif kind == "kde":
#    1979         from .distributions import kdeplot  # Avoid circular import
# -> 1980         plotter(kdeplot, **plot_kws)
#    1981     elif kind == "hist":
# ...

# %%
df= sns.load_dataset("iris")
df.boxplot(figsize=(12,7))
# Out:
# <AxesSubplot:>

# %%
sns.swarmplot(forbes[forbes['Industries']=='Technology']['Industries'],forbes['Net Worth']);
# Out:
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 49.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(forbes[forbes['Industries']=='Technology']['Industries'],forbes['Net Worth'],hue=forbes['Country']);
# Out:
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(forbes['Industries'],forbes['Age'],hue=forbes['Country']);
# Out:
# F:\Users\Debadutta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#sns.countplot(forbes['Industries'],hue=forbes['Country'])

# %%
#sns.pointplot(forbes['Industries'],forbes['Net Worth'],hue=forbes['Country'])

# %%
sns.catplot(x="Industries",y="Age",hue="Country",col="Source",data=forbes,kind="violin");

# %%
#sns.lmplot(x="Age",y="Net Worth",hue="Country",data=forbes)

# %%
#plt.plot(forbes[forbes['Industries']=='Technology']['Industries'],forbes['Net Worth'])

# %%
#plt.bar(forbes['Industries'],forbes['Age']),columns=('name','count'))
industries=pd.DataFrame(forbes['Industries'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\Users\Debadutta\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Industries', 1)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-eae835752517> in <module>
# ...

# %%
plt.pie(forbes['Industries'].value_counts,labels=forbes['Industries'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-d2bffed8a769> in <module>
# ----> 1 plt.pie(forbes['Industries'].value_counts,labels=forbes['Industries'])
#
# F:\Users\Debadutta\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# F:\Users\Debadutta\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
