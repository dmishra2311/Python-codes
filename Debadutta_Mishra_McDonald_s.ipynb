# %%
#Import required packages
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Read the file
df = pd.read_csv("Mcdonald.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.00                         20           5.00
# 1                 70       8.00                         12           3.00
# 2                200      23.00                         35           8.00
# 3                250      28.00                         43          10.00
# 4                210      23.00                         35           8.00
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
#Q1
from matplotlib.pyplot  import figure
figure(figsize=(10, 10), dpi=80)
sns.countplot(df["Category"], order = df["Category"].value_counts().index)
plt.xticks(rotation='45')
plt.show()

# %% [markdown]
# Q1
# > We can infer from the above plot, that 'Coffee & Tea' have the most varieties. Whereas 'Salads' have the least of varieties.
#
# > We can also assume from the above plot that the varieties of  'beverage' and 'Chicken & Fish' are almost the same.
#
# > We can also assume that there is a good demand for the category 'Coffee & Tea', hence so many varieties and hence could be one of the prime contributors to Revenue generation.

# %%
# Assigning measure columns to a variable
columns1 = df.columns
columns1 = columns1.drop('Category')
columns1 = columns1.drop('Item')
columns1
# Out:
# Index(['Serving Size', 'Calories', 'Calories from Fat', 'Total Fat',
#        'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
# Describing the data
df.describe().T
# Out:
#                                count   mean    std  min    25%    50%    75%  \
# Calories                      260.00 368.27 240.27 0.00 210.00 340.00 500.00
# Calories from Fat             260.00 127.10 127.88 0.00  20.00 100.00 200.00
# Total Fat                     260.00  14.17  14.21 0.00   2.38  11.00  22.25
# Total Fat (% Daily Value)     260.00  21.82  21.89 0.00   3.75  17.00  35.00
# Saturated Fat                 260.00   6.01   5.32 0.00   1.00   5.00  10.00
# Saturated Fat (% Daily Value) 260.00  29.97  26.64 0.00   4.75  24.00  48.00
# Trans Fat                     260.00   0.20   0.43 0.00   0.00   0.00   0.00
# Cholesterol                   260.00  54.94  87.27 0.00   5.00  35.00  65.00
# Cholesterol (% Daily Value)   260.00  18.39  29.09 0.00   2.00  11.00  21.25
# Sodium                        260.00 495.75 577.03 0.00 107.50 190.00 865.00
# Sodium (% Daily Value)        260.00  20.68  24.03 0.00   4.75   8.00  36.25
# ...

# %%
#Changing 'Serving Size' to int datatype
#Q2
df['Serving Size'] = df['Serving Size'].str.replace(r'\D', '').astype(int)
for i in columns1:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# Q2
# > From the above boxplots we can infer that except 'Saturated Fat', 'Saturated Fat(%daily value)' and 'Dietary Fiber', all other columns with a numeric value have outliers

# %%
#Q3
dfcorr = df.corr().abs()
dfs = dfcorr.unstack()
dfsort = dfs.sort_values(kind="quicksort")
dfsort.sort_values(ascending = False).head(50)
# Out:
# Iron (% Daily Value)           Iron (% Daily Value)            1.00
# Cholesterol                    Cholesterol                     1.00
# Serving Size                   Serving Size                    1.00
# Vitamin C (% Daily Value)      Vitamin C (% Daily Value)       1.00
# Calories                       Calories                        1.00
# Calories from Fat              Calories from Fat               1.00
# Total Fat                      Total Fat                       1.00
# Total Fat (% Daily Value)      Total Fat (% Daily Value)       1.00
# Saturated Fat                  Saturated Fat                   1.00
# Saturated Fat (% Daily Value)  Saturated Fat (% Daily Value)   1.00
# Trans Fat                      Trans Fat                       1.00
# Sodium                         Sodium                          1.00
# Calcium (% Daily Value)        Calcium (% Daily Value)         1.00
# Dietary Fiber (% Daily Value)  Dietary Fiber (% Daily Value)   1.00
# ...

# %% [markdown]
# Q3
# > If we see the above data , columns like 'Sodium' and 'Sodium (% Daily Value)','Cholesterol'and 'Cholesterol (% Daily Value)', 'Calories' and 'Calories from Fat', 'Iron (% Daily Value)' and 'Sodium' etc. have the highest correlations.

# %%
#Q3
figure(figsize=(10, 10), dpi=80)
sns.heatmap(df.corr(), cmap="mako")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q3
# > Above heatmap clearly shows the columns that have a high correlation.

# %%
#Q4
figure(figsize=(10, 10), dpi=80)
sns.lineplot(df['Category'], df['Cholesterol (% Daily Value)'],marker='o' )
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# Q4
# > We can infer from the above plot that 'Breakfast' contributes to the maximum % of 'Cholesterol in a diet (% daily value)' and 'Beverages' the least.
#
# > 'Breakfast' can be a prime contributor for Obesity in most McDonald's customers.

# %%
df[df["Sodium (% Daily Value)"]==df["Sodium (% Daily Value)"].max()]["Item"]
# Out:
# 82    Chicken McNuggets (40 piece)
# Name: Item, dtype: object

# %% [markdown]
# Q5
# > 'Chicken McNuggets (40 piece)' Contributes maximum to the Sodium intake.

# %%
df[df["Saturated Fat (% Daily Value)"]==df["Saturated Fat (% Daily Value)"].max()]["Item"]
df[["Item","Saturated Fat (% Daily Value)"]].sort_values("Saturated Fat (% Daily Value)",ascending=False)
# Out:
#                                               Item  \
# 253           McFlurry with M&M’s Candies (Medium)
# 82                    Chicken McNuggets (40 piece)
# 231                  Frappé Chocolate Chip (Large)
# 32     Big Breakfast with Hotcakes (Large Biscuit)
# 31   Big Breakfast with Hotcakes (Regular Biscuit)
# ..                                             ...
# 118                              Dr Pepper (Small)
# 119                             Dr Pepper (Medium)
# 120                              Dr Pepper (Large)
# 121                              Dr Pepper (Child)
# 127                                Sprite (Medium)
#
#      Saturated Fat (% Daily Value)
# 253                            102
# 82                             101
# 231                            101
# 32                             100
# 31                              96
# ..                             ...
# 118                              0
# 119                              0
# ...

# %% [markdown]
# Q6
# > 'McFlurry with M&M’s Candies (Medium)','Chicken McNuggets (40 piece)','Frappé Chocolate Chip (Large)' and 'Big Breakfast with Hotcakes (Large Biscuit)' contain the most amount of Saturated Fat.
